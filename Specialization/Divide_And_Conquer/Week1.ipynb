# %% [markdown]
# Topics covered are:
#
# **1. Karatsuba Multiplication**
#     Given that we have X=5678 and Y=1234
#     *Step 1: Compute a&ast;c=672*
#     *Step 2: Compute b&ast;d=2652*
#     *Step 3: Compute (a+b)&ast;(c+d)=134&ast;46=6164*
#     *Step 4: Compute Step3-Step2-Step1*
#     *Step 5: Pad the result from Step1 with 4 zeroes, add the result from Step2 and pad the result from Step4 with two more zeroes and add. The result is the answer.*
#    Why does it work?
#    X&ast;Y=(10^(n//2)+b)&ast;(10^(n//2)+b) => X&ast;Y=(10^n)&ast;(a&ast;b)+10^(n//2)&ast;(a&ast;b+b&ast;c)+b&ast;d
#    This is nothing but what we did in Step 5
#    These steps when done recursively, so, what happens to the base case:
#    Happens when n=1, where the second and the third terms vanish
#    and the algorithm works.
#    Why does the step 4 work? Recall Gauss's trick

# %%
#Code for Karatsuba

def Karatsuba(X,Y):
    X1=str(X)
    Y1=str(Y)
    N1=len(X1)
    N2=len(X2)
    if N1

# %% [markdown]
# **2. Merge Sort**

# %% [markdown]
# **3. Bonus: Mergesort counting the inversions**

# %% [markdown]
# **4. Asymptotic analysis**
